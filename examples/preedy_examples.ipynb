# %% [markdown]
# Examples
# ---
#
# - [digits](#Digits)
# - [IRIS](#IRIS)
# - [Wine](#Wine)
# - [Breast Cancer](#Breast-Cancer)

# %%
import emby
import matplotlib.pyplot as plt
import matplotlib.colors as mcolors
import numpy as np
import time

# %% [markdown]
# Digits
# ---

# %%
# %%time
from sklearn.datasets import load_digits

digits = load_digits()

x = digits.data
y = digits.target

x = x - x.mean()

mm = emby.Preedy(Z=2, 
                 alpha=0.4,
                 beta=5.0,
                 n=25,
                 device=emby.Device.CPU,
                 logging=emby.Logging.Nothing)

colors = np.array(list(mcolors.TABLEAU_COLORS.values()))

timestamp = time.time()
embeddings = mm.fit_transform(x)
print(f"Time to fit transform {time.time() - timestamp}")

plt.figure(figsize=(8, 8))
plt.scatter(embeddings[:, 0], embeddings[:, 1], color=colors[y])
plt.show()
# Out:
# Time to fit transform 5.580657243728638
# CPU times: user 5.95 s, sys: 228 ms, total: 6.18 s
# Wall time: 5.9 s

# %% [markdown]
# IRIS
# ---

# %%
# %%time
from sklearn.datasets import load_iris

iris = load_iris()

x = iris.data
y = iris.target

x = x - x.mean()


mm = emby.Preedy(Z=2, 
                 alpha=2.0,
                 beta=10.0,
                 n=8,
                 device=emby.Device.CPU,
                 logging=emby.Logging.Nothing)

colors = np.array(list(mcolors.TABLEAU_COLORS.values()))

timestamp = time.time()
embeddings = mm.fit_transform(x)
print(f"Time to fit transform {time.time() - timestamp}")

plt.figure(figsize=(8, 8))
plt.scatter(embeddings[:, 0], embeddings[:, 1], color=colors[y])
plt.show()
# Out:
# Time to fit transform 0.18502330780029297
# CPU times: user 416 ms, sys: 204 ms, total: 621 ms
# Wall time: 348 ms

# %% [markdown]
# Wine
# ---

# %%
# %%time
from sklearn.datasets import load_wine

wine = load_wine()

x = wine.data
y = wine.target

x = x - x.mean()

mm = emby.Preedy(Z=2, 
                 alpha=1.0,
                 beta=10.0,
                 n=4,
                 device=emby.Device.CPU,
                 logging=emby.Logging.Nothing)


colors = np.array(list(mcolors.TABLEAU_COLORS.values()))

timestamp = time.time()
embeddings = mm.fit_transform(x)
print(f"Time to fit transform {time.time() - timestamp}")

plt.figure(figsize=(8, 8))
plt.scatter(embeddings[:, 0], embeddings[:, 1], color=colors[y])
plt.show()
# Out:
# Time to fit transform 0.7299962043762207
# CPU times: user 957 ms, sys: 217 ms, total: 1.17 s
# Wall time: 899 ms

# %% [markdown]
# Breast Cancer
# ---

# %%
# %%time
from sklearn.datasets import load_breast_cancer

bc = load_breast_cancer()

x = bc.data
y = bc.target


mm = emby.Preedy(Z=2, 
                 alpha=1.0,
                 beta=5.0,
                 n=35,
                 device=emby.Device.CPU,
                 logging=emby.Logging.Nothing)

colors = np.array(list(mcolors.TABLEAU_COLORS.values()))

timestamp = time.time()
embeddings = mm.fit_transform(x)
print(f"Time to fit transform {time.time() - timestamp}")

plt.figure(figsize=(8, 8))
plt.scatter(embeddings[:, 0], embeddings[:, 1], color=colors[y])
plt.show()
# Out:
# Time to fit transform 0.4739828109741211
# CPU times: user 741 ms, sys: 196 ms, total: 937 ms
# Wall time: 664 ms
